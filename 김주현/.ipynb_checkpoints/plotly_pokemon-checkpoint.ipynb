# %% [markdown]
# ## 리그 참여시 전설의 포켓몬 출전 불가 원인 분석

# %%
# pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org plotly

# %%
import pandas as pd
import numpy as np
import os

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %%
df = pd.read_csv("./pokemon.csv")

# %%
# df.isnull().sum()

# %% [markdown]
# ## preprocess

# %%
df.loc[df['type2'].isnull(), 'type2'] = df['type1']
df = df.fillna(0)

# %%
stats = ['attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed']
against = ['against_bug', 'against_dark', 'against_dragon',
       'against_electric', 'against_fairy', 'against_fight', 'against_fire',
       'against_flying', 'against_ghost', 'against_grass', 'against_ground',
       'against_ice', 'against_normal', 'against_poison', 'against_psychic',
       'against_rock', 'against_steel', 'against_water']

# %%
df.loc[df["is_legendary"]==1, "is_legendary"] = "Y"
df.loc[df["is_legendary"]==0, "is_legendary"] = "N"
df['avg'] = df[stats].mean(axis=1)
df['agst_avg'] = df[against].mean(axis=1)
df["stddev"]=df[stats].std(axis=1)
df["tmp"] = "_"
df["type_total"] = df["type1"]+df["tmp"]+df["type2"]
# df['generation'] = df['generation'].astype(str)+df["tmp"]
df = df.drop("tmp", axis=1)

# %%
DF_legend = df.loc[df["is_legendary"]=="Y"]
DF_nonlegend = df.loc[df["is_legendary"]=="N"]

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  speed  type1   type2  weight_kg  \
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary', 'avg', 'agst_avg', 'stddev',
#        'type_total'],
#       dtype='object')

# %% [markdown]
# ## START

# %%
fig = px.box(df
             , x="type_total"
             , y="base_total"
             , color="is_legendary"
             , hover_data=df.columns
             , 
            )
fig.show()
# Out:
# <div>                            <div id="e10ce018-864c-4547-acaa-71622072cf8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e10ce018-864c-4547-acaa-71622072cf8f")) {                    Plotly.newPlot(                        "e10ce018-864c-4547-acaa-71622072cf8f",                        [{"alignmentgroup": "True", "customdata": [["['Overgrow', 'Chlorophyll']", 1.0, 1.0, 1.0, 0.5, 0.5, 0.5, 2.0, 2.0, 1.0, 0.25, 1.0, 2.0, 1.0, 1.0, 2.0, 1.0, 1.0, 0.5, 49, 5120, 70, 318, "45", "Seed Pok\u00e9mon", 49, 1059860, 0.7, 45, "Fushigidane\u30d5\u30b7\u30ae\u30c0\u30cd", "Bulbasaur", 88.1, 1, 65, 65, 45, "grass", "poison", 6.9, 1, "N", 53.0, 1.0694444444444444, 9.465727652959385, "grass_poison"], ["['Overgrow', 'Chlorophyll']", 1.0, 1.0, 1.0, 0.5, 0.5, 0.5,
# ...

# %%
hist_data = [
              df['base_total']
            ]

group_labels = ['base_total']

fig = ff.create_distplot(hist_data, group_labels
                          , bin_size=5
                        )
fig.show()
# Out:
# <div>                            <div id="d63e4f72-8f24-41d6-b00b-97a3b6af1462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d63e4f72-8f24-41d6-b00b-97a3b6af1462")) {                    Plotly.newPlot(                        "d63e4f72-8f24-41d6-b00b-97a3b6af1462",                        [{"autobinx": false, "histnorm": "probability density", "legendgroup": "base_total", "marker": {"color": "rgb(31, 119, 180)"}, "name": "base_total", "opacity": 0.7, "type": "histogram", "x": [318, 405, 625, 309, 405, 634, 314, 405, 630, 195, 205, 395, 195, 205, 495, 251, 349, 579, 253, 413, 262, 442, 288, 448, 320, 485, 300, 450, 275, 365, 505, 273, 365, 505, 323, 483, 299, 505, 270, 435, 245, 455, 320, 395, 490, 285, 405, 305, 450, 265, 425, 290, 440, 320, 500, 3
# ...

# %%
hist_data = [
              DF_nonlegend['base_total']
              ,df['base_total']
            ]

group_labels = [
                'N, base_total'
                 , 'Y include, base_total'
               ]

fig = ff.create_distplot(hist_data, group_labels
                          , bin_size=5
                          , histnorm = 'probability'
                        )
fig.show()
# Out:
# <div>                            <div id="72554319-e256-41c7-a1a0-5fdb38503388" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72554319-e256-41c7-a1a0-5fdb38503388")) {                    Plotly.newPlot(                        "72554319-e256-41c7-a1a0-5fdb38503388",                        [{"autobinx": false, "histnorm": "probability", "legendgroup": "N, base_total", "marker": {"color": "rgb(31, 119, 180)"}, "name": "N, base_total", "opacity": 0.7, "type": "histogram", "x": [318, 405, 625, 309, 405, 634, 314, 405, 630, 195, 205, 395, 195, 205, 495, 251, 349, 579, 253, 413, 262, 442, 288, 448, 320, 485, 300, 450, 275, 365, 505, 273, 365, 505, 323, 483, 299, 505, 270, 435, 245, 455, 320, 395, 490, 285, 405, 305, 450, 265, 425, 290, 440, 320, 500, 305
# ...

# %%
hist_data = [
              DF_legend['attack']
             ,DF_legend['defense']
             ,DF_legend['hp']
             ,DF_legend['sp_attack']
             ,DF_legend['sp_defense']
             ,DF_legend['speed']
             ,DF_nonlegend['attack']
             ,DF_nonlegend['defense']
             ,DF_nonlegend['hp']
             ,DF_nonlegend['sp_attack']
             ,DF_nonlegend['sp_defense']
             ,DF_nonlegend['speed']
            ]

group_labels = ['Y,attack', 'Y,defense', 'Y,hp', 'Y,sp_attack', 'Y,sp_defense', 'Y,speed'
                , 'N, attack', 'N, defense', 'N, hp', 'N, sp_attack', 'N, sp_defense', 'N, speed']

fig = ff.create_distplot(hist_data, group_labels
                          , bin_size=5
                        )
fig.show()
# Out:
# <div>                            <div id="765be66b-1dd0-4752-86c3-7de0e23abb1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("765be66b-1dd0-4752-86c3-7de0e23abb1e")) {                    Plotly.newPlot(                        "765be66b-1dd0-4752-86c3-7de0e23abb1e",                        [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Y,attack", "marker": {"color": "rgb(31, 119, 180)"}, "name": "Y,attack", "opacity": 0.7, "type": "histogram", "x": [85, 90, 100, 150, 100, 85, 115, 75, 90, 130, 100, 100, 50, 75, 100, 130, 150, 180, 180, 100, 95, 75, 105, 125, 120, 120, 90, 160, 120, 70, 100, 90, 103, 120, 100, 90, 129, 90, 100, 105, 120, 150, 145, 120, 72, 128, 120, 131, 131, 100, 160, 160, 110, 115, 85, 130, 75, 29, 29, 137,
# ...

# %%
fig = px.scatter_3d(df, x='attack', y='defense', z='hp', size='base_total', color='is_legendary'
                    , hover_data=['name']
                   )
#fig.update_layout(scene_zaxis_type="log")
fig.show()
# Out:
# <div>                            <div id="ce318465-544e-4474-9b01-81fa59261646" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce318465-544e-4474-9b01-81fa59261646")) {                    Plotly.newPlot(                        "ce318465-544e-4474-9b01-81fa59261646",                        [{"customdata": [["Bulbasaur"], ["Ivysaur"], ["Venusaur"], ["Charmander"], ["Charmeleon"], ["Charizard"], ["Squirtle"], ["Wartortle"], ["Blastoise"], ["Caterpie"], ["Metapod"], ["Butterfree"], ["Weedle"], ["Kakuna"], ["Beedrill"], ["Pidgey"], ["Pidgeotto"], ["Pidgeot"], ["Rattata"], ["Raticate"], ["Spearow"], ["Fearow"], ["Ekans"], ["Arbok"], ["Pikachu"], ["Raichu"], ["Sandshrew"], ["Sandslash"], ["Nidoran\u2640"], ["Nidorina"], ["Nidoqueen"], ["Nidoran\u2642"], [
# ...

# %%
fig = px.scatter(df, x="base_total", y="agst_avg",
                 color = 'type_total',
                hover_data=['name'])
fig.show()
# Out:
# <div>                            <div id="4c05e1e2-2d20-4a67-9937-4fe4473bc5ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c05e1e2-2d20-4a67-9937-4fe4473bc5ae")) {                    Plotly.newPlot(                        "4c05e1e2-2d20-4a67-9937-4fe4473bc5ae",                        [{"customdata": [["Bulbasaur"], ["Ivysaur"], ["Venusaur"], ["Oddish"], ["Gloom"], ["Vileplume"], ["Bellsprout"], ["Weepinbell"], ["Victreebel"], ["Roselia"], ["Budew"], ["Roserade"], ["Foongus"], ["Amoonguss"]], "hovertemplate": "type_total=grass_poison<br>base_total=%{x}<br>agst_avg=%{y}<br>name=%{customdata[0]}<extra></extra>", "legendgroup": "grass_poison", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "grass_poison", "orientati
# ...

# %% [markdown]
# ## 누가더 좋을까?

# %%
# check upper
DF_legendU = DF_legend.loc[DF_legend["base_total"]>=650]
DF_nonlegendU = DF_nonlegend.loc[DF_nonlegend["base_total"]>=600]

# %%
fig = px.scatter_3d(DF_legendU, x='attack', y='defense', z='base_total', size='hp', color='type_total'
                    , hover_data=['pokedex_number','name']
                   )
fig.update_layout(scene_zaxis_type="log")
fig.show()
# Out:
# <div>                            <div id="fe5460b8-f579-46cc-9cc0-6302f29e24fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe5460b8-f579-46cc-9cc0-6302f29e24fb")) {                    Plotly.newPlot(                        "fe5460b8-f579-46cc-9cc0-6302f29e24fb",                        [{"customdata": [[150, "Mewtwo"]], "hovertemplate": "type_total=psychic_psychic<br>attack=%{x}<br>defense=%{y}<br>base_total=%{z}<br>hp=%{marker.size}<br>pokedex_number=%{customdata[0]}<br>name=%{customdata[1]}<extra></extra>", "legendgroup": "psychic_psychic", "marker": {"color": "#636efa", "size": [106], "sizemode": "area", "sizeref": 0.54, "symbol": "circle"}, "mode": "markers", "name": "psychic_psychic", "scene": "scene", "showlegend": true, "type": "scatter3d
# ...

# %%
fig = px.scatter(DF_legendU, x="base_total", y="agst_avg",
                 color = 'type_total',
                hover_data=['name'])
fig.show()
# Out:
# <div>                            <div id="3292ace3-d889-4788-97c1-be26d9e25bae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3292ace3-d889-4788-97c1-be26d9e25bae")) {                    Plotly.newPlot(                        "3292ace3-d889-4788-97c1-be26d9e25bae",                        [{"customdata": [["Mewtwo"]], "hovertemplate": "type_total=psychic_psychic<br>base_total=%{x}<br>agst_avg=%{y}<br>name=%{customdata[0]}<extra></extra>", "legendgroup": "psychic_psychic", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "psychic_psychic", "orientation": "v", "showlegend": true, "type": "scatter", "x": [780], "xaxis": "x", "y": [1.1111111111111112], "yaxis": "y"}, {"customdata": [["Lugia"]], "hovertemplate": "type_total
# ...

# %%
def compare2pokemon(x,y):
    x = df[df["name"] == x]
    y = df[df["name"] == y]

    trace0 = go.Scatterpolar(
      r = [x['attack'].values[0],x['defense'].values[0],x['hp'].values[0],x['sp_attack'].values[0]
           ,x['sp_defense'].values[0],x['speed'].values[0],x['attack'].values[0]],
      theta = ['attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed','attack'],
      fill = 'toself',
      name = x.name.values[0]
    )

    trace1 = go.Scatterpolar(
      r = [y['attack'].values[0],y['defense'].values[0],y['hp'].values[0],y['sp_attack'].values[0]
           ,y['sp_defense'].values[0],y['speed'].values[0],y['attack'].values[0]],
      theta = ['attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed','attack'],
      fill = 'toself',
      name = y.name.values[0]
    )

    data = [trace0, trace1]

    layout = go.Layout(
      polar = dict(
        radialaxis = dict(
          visible = True,
          range = [0, 200]
        )
      ),
      showlegend = True,
      title = "{}-{} vs {}-{}".format(x.name.values[0],x.type_total.values[0],y.name.values[0],y.type_total.values[0])
    )
    fig = go.Figure(data=data, layout=layout)
    fig.show()
#     iplot(fig, filename = "Two Pokemon stats")

# %%
compare2pokemon("Rayquaza","Mewtwo")
# Out:
# <div>                            <div id="174d7c3a-214f-4eb4-af54-49c41992e430" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("174d7c3a-214f-4eb4-af54-49c41992e430")) {                    Plotly.newPlot(                        "174d7c3a-214f-4eb4-af54-49c41992e430",                        [{"fill": "toself", "name": "Rayquaza", "r": [180, 100, 105, 180, 100, 115, 180], "theta": ["attack", "defense", "hp", "sp_attack", "sp_defense", "speed", "attack"], "type": "scatterpolar"}, {"fill": "toself", "name": "Mewtwo", "r": [150, 70, 106, 194, 120, 140, 150], "theta": ["attack", "defense", "hp", "sp_attack", "sp_defense", "speed", "attack"], "type": "scatterpolar"}],                        {"polar": {"radialaxis": {"range": [0, 200], "visible": true}}, "s
# ...

# %%
DF_SUB = df.loc[(df['name']=='Rayquaza')|(df['name']=="Mewtwo")|(df['name']=="Groudon")|(df['name']=="Kyogre")
               |(df['name']=="Dialga")|(df['name']=="Arceus")
               ]
fig = px.bar(DF_SUB, x=against, y='name', hover_data=['type_total'])
fig.show()

# ag_normal : Dialga > Arceus
# ag_steeldrgon : Kyogre > Dialga > Rayquaza
# ag_dragonFly : Dialga > Rayquaza
# ag_ground : Rayquaza > Groudon > Dialga
# ag_water : (Dialga > Rayquaza) > Kyogre > Groudon
# ag_psy : Dialga > Mewtwo 

# Groudon > Dialga > Rayquaza > Kyogre > Groudon
# Dialga만 조심하면 Mewtwo가 범용적이고 강력하다.
# Out:
# <div>                            <div id="7596182c-34ea-44fb-8879-31418ba4e2ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7596182c-34ea-44fb-8879-31418ba4e2ab")) {                    Plotly.newPlot(                        "7596182c-34ea-44fb-8879-31418ba4e2ab",                        [{"alignmentgroup": "True", "customdata": [["psychic_psychic"], ["water_water"], ["ground_ground"], ["dragon_flying"], ["steel_dragon"], ["normal_normal"]], "hovertemplate": "variable=against_bug<br>value=%{x}<br>name=%{y}<br>type_total=%{customdata[0]}<extra></extra>", "legendgroup": "against_bug", "marker": {"color": "#636efa"}, "name": "against_bug", "offsetgroup": "against_bug", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x"
# ...

# %%
fig = px.scatter_3d(DF_nonlegendU, x='attack', y='defense', z='base_total', size='hp', color='type_total'
                    , hover_data=['pokedex_number','name']
                   )
fig.update_layout(scene_zaxis_type="log")
fig.show()
# Out:
# <div>                            <div id="7950e415-34f2-43c1-8b55-a451365fefa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7950e415-34f2-43c1-8b55-a451365fefa5")) {                    Plotly.newPlot(                        "7950e415-34f2-43c1-8b55-a451365fefa5",                        [{"customdata": [[3, "Venusaur"]], "hovertemplate": "type_total=grass_poison<br>attack=%{x}<br>defense=%{y}<br>base_total=%{z}<br>hp=%{marker.size}<br>pokedex_number=%{customdata[0]}<br>name=%{customdata[1]}<extra></extra>", "legendgroup": "grass_poison", "marker": {"color": "#636efa", "size": [80], "sizemode": "area", "sizeref": 0.375, "symbol": "circle"}, "mode": "markers", "name": "grass_poison", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [
# ...

# %%
fig = px.scatter(DF_nonlegendU, x="base_total", y="agst_avg",
                 color = 'type_total',
                hover_data=['name'])
fig.show()
# Out:
# <div>                            <div id="9b412292-c60d-4eb2-84a2-5f82afd9c1c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b412292-c60d-4eb2-84a2-5f82afd9c1c3")) {                    Plotly.newPlot(                        "9b412292-c60d-4eb2-84a2-5f82afd9c1c3",                        [{"customdata": [["Venusaur"]], "hovertemplate": "type_total=grass_poison<br>base_total=%{x}<br>agst_avg=%{y}<br>name=%{customdata[0]}<extra></extra>", "legendgroup": "grass_poison", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "grass_poison", "orientation": "v", "showlegend": true, "type": "scatter", "x": [625], "xaxis": "x", "y": [1.0694444444444444], "yaxis": "y"}, {"customdata": [["Charizard"]], "hovertemplate": "type_total=fi
# ...

# %%
DF_SUB_n = df.loc[(df['name']=='Tyranitar')|(df['name']=="Garchomp")|(df['name']=="Salamence")|(df['name']=="Metagross")]
fig = px.bar(DF_SUB_n, x=against, y='name', hover_data=['type_total'])
fig.show()

# Tyranitar < Garchomp
# Tyranitar < Garchomp < Salamense
# Metagross < Tyranitar
# Salamense < Metagross

# 결론 Tyranitar < Garchomp < Salamense < Metagross < Tyranitar
# 그 중에 젤 범용성 좋은건 Metagross
# Out:
# <div>                            <div id="2d37567c-2c0b-4230-889a-97f5f4234139" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d37567c-2c0b-4230-889a-97f5f4234139")) {                    Plotly.newPlot(                        "2d37567c-2c0b-4230-889a-97f5f4234139",                        [{"alignmentgroup": "True", "customdata": [["rock_dark"], ["dragon_flying"], ["steel_psychic"], ["dragon_ground"]], "hovertemplate": "variable=against_bug<br>value=%{x}<br>name=%{y}<br>type_total=%{customdata[0]}<extra></extra>", "legendgroup": "against_bug", "marker": {"color": "#636efa"}, "name": "against_bug", "offsetgroup": "against_bug", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2.0, 0.5, 1.0, 1.0], "xaxis": "x", "y"
# ...
